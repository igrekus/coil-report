# %% [markdown]
# ## Подготовительная работа

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('data/coil_stat.xlsx')
rows = sorted([f'V{n}{d:02d}' for d in range(2, 6) for n in range(2, 5)])
# rows += 
rects = df.loc[(df['file'].isin(rows))]

# %matplotlib inline

# %%
# f = 1/(2*pi*sqrt(LC)) -> 
rects['Lsqrt'] = rects['L, uH'].apply(lambda x: 1/math.sqrt(x))
rects['C, pF'] = rects.apply(lambda x: 1/(4*x['L, uH']*pow(math.pi, 2) * pow(x['freq'], 2)) * pow(10, 12), axis=1)
rects
# Out:
# <ipython-input-2-5d395bff814e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rects['Lsqrt'] = rects['L, uH'].apply(lambda x: 1/math.sqrt(x))
# <ipython-input-2-5d395bff814e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rects['C, pF'] = rects.apply(lambda x: 1/(4*x['L, uH']*pow(math.pi, 2) * pow(x['freq'], 2)) * pow(10, 12), axis=1)
#      file  wire_len (cm)  wire_dia (mm)  step (mm)  coil_n  width (mm)  \
# 64   V202         76.766           0.08        0.2     3.0        45.0
# 65   V202         76.766           0.10        0.2     3.0        45.0
# 66   V203         76.546           0.08        0.3     3.0        45.0
# 67   V203         76.546           0.10        0.3     3.0        45.0
# 68   V204         76.413           0.08        0.4     3.0        45.0
# 69   V204         76.413           0.10        0.4     3.0        45.0
# 70   V205         76.194           0.08        0.5     3.0        45.0
# 71   V205         76.194           0.10        0.5     3.0        45.0
# 82   V302        100.611           0.08        0.2     4.0        45.0
# 83   V302        100.611           0.10        0.2     4.0        45.0
# 84   V303        100.207           0.08        0.3     4.0        45.0
# 85   V303        100.207           0.10        0.3     4.0        45.0
# 86   V304         99.858           0.08        0.4     4.0        45.0
# 87   V304         99.858           0.10        0.4     4.0        45.0
# 88   V305         99.494           0.08        0.5     4.0        45.0
# 89   V305         99.494           0.10        0.5     4.0        45.0
# 104  V402        124.296           0.08        0.2     5.0        45.0
# 105  V402        124.296           0.10        0.2     5.0        45.0
# 106  V403        123.598           0.08        0.3     5.0        45.0
# 107  V403        123.598           0.10        0.3     5.0        45.0
# 112  V404        122.903           0.08        0.4     5.0        45.0
# 113  V404        122.903           0.10        0.4     5.0        45.0
# 115  V405        122.217           0.08        0.5     5.0        45.0
# 116  V405        122.217           0.10        0.5     5.0        45.0
#
#      height (mm)  L, uH     freq     q     mod done     Lsqrt      C, pF
# 64          79.0  2.656  24000.0  22.0  rect-v  NaN  0.613601  16.557307
# 65          79.0  2.601  24000.0  22.0  rect-v  NaN  0.620054  16.907423
# 66          79.0  2.561  24000.0  22.0  rect-v  NaN  0.624878  17.171499
# 67          79.0  2.432  24000.0  22.0  rect-v  NaN  0.641236  18.082322
# 68          79.0  2.232  24000.0  22.0  rect-v  NaN  0.669349  19.702602
# 69          79.0  2.365  24000.0  22.0  rect-v  NaN  0.650256  18.594591
# 70          79.0  2.263  24000.0  22.0  rect-v  NaN  0.664749  19.432704
# 71          79.0  2.167  24000.0  22.0  rect-v  NaN  0.679314  20.293589
# 82          79.0  4.029  19140.0  63.0  rect-v  NaN  0.498197  17.161653
# 83          79.0  4.019  19250.0  67.0  rect-v  NaN  0.498817  17.008295
# 84          79.0  3.887  19940.0  57.0  rect-v  NaN  0.507216  16.389866
# 85          79.0  3.789  20160.0  66.0  rect-v  NaN  0.513733  16.448814
# 86          79.0  3.318  20720.0  68.0  rect-v  NaN  0.548987  17.782155
# 87          79.0  3.605  20880.0  71.0  rect-v  NaN  0.526681  16.116621
# 88          79.0  3.437  21290.0  64.0  rect-v  NaN  0.539399  16.259583
# 89          79.0  3.458  21320.0  73.0  rect-v  NaN  0.537759  16.115392
# 104         79.0  5.899  15630.0  59.0  rect-v  NaN  0.411728  17.576966
# 105         79.0  5.835  15690.0  66.0  rect-v  NaN  0.413980  17.634109
# 106         79.0  5.551  16500.0  60.0  rect-v  NaN  0.424438  16.761047
# 107         79.0  5.471      NaN   NaN  rect-v  NaN  0.427530        NaN
# 112         79.0  5.223  17000.0  60.0  rect-v  NaN  0.437562  16.781176
# 113         79.0  5.038  17250.0  69.0  rect-v  NaN  0.445524  16.896778
# 115         79.0  5.118  17490.0  60.0  rect-v  NaN  0.442028  16.179324
# 116         79.0  5.187  17710.0  70.0  rect-v  NaN  0.439078  15.569938

# %%
cmid = rects['C, pF']
cmid = list(cmid)

# %%
rects_cmid = [['V202', 76.5, 0.08, 1.26, 16.56, 34909.99, 0.28], ['V202', 76.5, 0.1, 1.25, 16.91, 34609.36, 0.27], ['V203', 76.5, 0.08, 1.18, 17.17, 35368.2, 0.26], ['V203', 76.5, 0.1, 1.18, 18.08, 34512.21, 0.26], ['V204', 76.5, 0.08, 1.12, 19.7, 33825.72, 0.24], ['V204', 76.5, 0.1, 1.12, 18.59, 34856.65, 0.25], ['V205', 76.5, 0.08, 1.08, 19.43, 34746.86, 0.24], ['V205', 76.5, 0.1, 1.08, 20.29, 34033.07, 0.23], ['V302', 100.2, 0.08, 2.65, 17.16, 23585.56, 0.39], ['V302', 100.2, 0.1, 2.65, 17.01, 23723.47, 0.39], ['V303', 100.2, 0.08, 2.48, 16.39, 24983.14, 0.39], ['V303', 100.2, 0.1, 2.47, 16.45, 24963.08, 0.39], ['V304', 100.2, 0.08, 2.35, 17.78, 24635.54, 0.36], ['V304', 100.2, 0.1, 2.34, 16.12, 25897.95, 0.38], ['V305', 100.2, 0.08, 2.25, 16.26, 26341.28, 0.37], ['V305', 100.2, 0.1, 2.24, 16.12, 26476.9, 0.37], ['V402', 123.2, 0.08, 4.49, 17.58, 17906.34, 0.51], ['V402', 123.2, 0.1, 4.48, 17.63, 17896.67, 0.5], ['V403', 123.2, 0.08, 4.17, 16.76, 19031.14, 0.5], ['V403', 123.2, 0.1, 4.17, 1000, 2465.83, 0.06], ['V404', 123.2, 0.08, 3.94, 16.78, 19576.72, 0.48], ['V404', 123.2, 0.1, 3.93, 16.9, 19522.34, 0.48], ['V405', 123.2, 0.08, 3.75, 16.18, 20422.58, 0.48], ['V405', 123.2, 0.1, 3.75, 15.57, 20829.96, 0.49]]
rects_approx_c = [['V202', 76.5, 0.08, 1.26, 17.19, 34262.31, 0.27], ['V202', 76.5, 0.1, 1.25, 17, 34515.0, 0.27], ['V203', 76.5, 0.08, 1.18, 6.89, 55836.35, 0.41], ['V203', 76.5, 0.1, 1.18, 10.06, 46281.56, 0.34], ['V204', 76.5, 0.08, 1.12, 5.03, 66962.54, 0.47], ['V204', 76.5, 0.1, 1.12, 6.34, 59675.57, 0.42], ['V205', 76.5, 0.08, 1.08, 4.2, 74713.61, 0.51], ['V205', 76.5, 0.1, 1.08, 5.03, 68375.99, 0.46], ['V302', 100.2, 0.08, 2.65, 22.51, 20591.82, 0.34], ['V302', 100.2, 0.1, 2.65, 17, 23729.26, 0.39], ['V303', 100.2, 0.08, 2.48, 9.02, 33669.11, 0.52], ['V303', 100.2, 0.1, 2.47, 13.17, 27897.83, 0.43], ['V304', 100.2, 0.08, 2.35, 6.59, 40483.14, 0.6], ['V304', 100.2, 0.1, 2.34, 8.31, 36067.57, 0.53], ['V305', 100.2, 0.08, 2.25, 5.51, 45269.52, 0.64], ['V305', 100.2, 0.1, 2.24, 6.59, 41419.75, 0.58], ['V402', 123.2, 0.08, 4.49, 27.68, 14268.43, 0.4], ['V402', 123.2, 0.1, 4.48, 17, 18227.39, 0.51], ['V403', 123.2, 0.08, 4.17, 11.1, 23390.57, 0.61], ['V403', 123.2, 0.1, 4.17, 16.19, 19377.47, 0.51], ['V404', 123.2, 0.08, 3.94, 8.1, 28183.8, 0.7], ['V404', 123.2, 0.1, 3.93, 10.22, 25105.95, 0.62], ['V405', 123.2, 0.08, 3.75, 6.77, 31574.29, 0.74], ['V405', 123.2, 0.1, 3.75, 8.1, 28885.53, 0.68]]

# %%
rects_cmid = pd.DataFrame(rects_cmid, columns=['file', 'len', 'dia', 'L', 'C', 'F', 'Q'])
rects_cmid['Lsqrt'] = rects_cmid['L'].apply(lambda x: 1/math.sqrt(x))
rects_cmid
# Out:
#     file    len   dia     L        C         F     Q     Lsqrt
# 0   V202   76.5  0.08  1.26    16.56  34909.99  0.28  0.890871
# 1   V202   76.5  0.10  1.25    16.91  34609.36  0.27  0.894427
# 2   V203   76.5  0.08  1.18    17.17  35368.20  0.26  0.920575
# 3   V203   76.5  0.10  1.18    18.08  34512.21  0.26  0.920575
# 4   V204   76.5  0.08  1.12    19.70  33825.72  0.24  0.944911
# 5   V204   76.5  0.10  1.12    18.59  34856.65  0.25  0.944911
# 6   V205   76.5  0.08  1.08    19.43  34746.86  0.24  0.962250
# 7   V205   76.5  0.10  1.08    20.29  34033.07  0.23  0.962250
# 8   V302  100.2  0.08  2.65    17.16  23585.56  0.39  0.614295
# 9   V302  100.2  0.10  2.65    17.01  23723.47  0.39  0.614295
# 10  V303  100.2  0.08  2.48    16.39  24983.14  0.39  0.635001
# 11  V303  100.2  0.10  2.47    16.45  24963.08  0.39  0.636285
# 12  V304  100.2  0.08  2.35    17.78  24635.54  0.36  0.652328
# 13  V304  100.2  0.10  2.34    16.12  25897.95  0.38  0.653720
# 14  V305  100.2  0.08  2.25    16.26  26341.28  0.37  0.666667
# 15  V305  100.2  0.10  2.24    16.12  26476.90  0.37  0.668153
# 16  V402  123.2  0.08  4.49    17.58  17906.34  0.51  0.471929
# 17  V402  123.2  0.10  4.48    17.63  17896.67  0.50  0.472456
# 18  V403  123.2  0.08  4.17    16.76  19031.14  0.50  0.489702
# 19  V403  123.2  0.10  4.17  1000.00   2465.83  0.06  0.489702
# 20  V404  123.2  0.08  3.94    16.78  19576.72  0.48  0.503793
# 21  V404  123.2  0.10  3.93    16.90  19522.34  0.48  0.504433
# 22  V405  123.2  0.08  3.75    16.18  20422.58  0.48  0.516398
# 23  V405  123.2  0.10  3.75    15.57  20829.96  0.49  0.516398

# %%
rects_approx_c = pd.DataFrame(rects_approx_c, columns=['file', 'len', 'dia', 'L', 'C', 'F', 'Q'])
rects_approx_c['Lsqrt'] = rects_approx_c['L'].apply(lambda x: 1/math.sqrt(x))
rects_approx_c
# Out:
#     file    len   dia     L      C         F     Q     Lsqrt
# 0   V202   76.5  0.08  1.26  17.19  34262.31  0.27  0.890871
# 1   V202   76.5  0.10  1.25  17.00  34515.00  0.27  0.894427
# 2   V203   76.5  0.08  1.18   6.89  55836.35  0.41  0.920575
# 3   V203   76.5  0.10  1.18  10.06  46281.56  0.34  0.920575
# 4   V204   76.5  0.08  1.12   5.03  66962.54  0.47  0.944911
# 5   V204   76.5  0.10  1.12   6.34  59675.57  0.42  0.944911
# 6   V205   76.5  0.08  1.08   4.20  74713.61  0.51  0.962250
# 7   V205   76.5  0.10  1.08   5.03  68375.99  0.46  0.962250
# 8   V302  100.2  0.08  2.65  22.51  20591.82  0.34  0.614295
# 9   V302  100.2  0.10  2.65  17.00  23729.26  0.39  0.614295
# 10  V303  100.2  0.08  2.48   9.02  33669.11  0.52  0.635001
# 11  V303  100.2  0.10  2.47  13.17  27897.83  0.43  0.636285
# 12  V304  100.2  0.08  2.35   6.59  40483.14  0.60  0.652328
# 13  V304  100.2  0.10  2.34   8.31  36067.57  0.53  0.653720
# 14  V305  100.2  0.08  2.25   5.51  45269.52  0.64  0.666667
# 15  V305  100.2  0.10  2.24   6.59  41419.75  0.58  0.668153
# 16  V402  123.2  0.08  4.49  27.68  14268.43  0.40  0.471929
# 17  V402  123.2  0.10  4.48  17.00  18227.39  0.51  0.472456
# 18  V403  123.2  0.08  4.17  11.10  23390.57  0.61  0.489702
# 19  V403  123.2  0.10  4.17  16.19  19377.47  0.51  0.489702
# 20  V404  123.2  0.08  3.94   8.10  28183.80  0.70  0.503793
# 21  V404  123.2  0.10  3.93  10.22  25105.95  0.62  0.504433
# 22  V405  123.2  0.08  3.75   6.77  31574.29  0.74  0.516398
# 23  V405  123.2  0.10  3.75   8.10  28885.53  0.68  0.516398

# %%
# res = dframe.loc[(dframe['coil_n'] == coil_n) & (dframe['wire_dia (mm)'] == wire)][['file', 'step (mm)', 'L, uH']]
# res = res.sort_values(['step (mm)'], ascending=[1])
ax = rects.plot.scatter(x='Lsqrt', y='freq', title=f'F от Lsqrt', label='Измерения')

# %%
ax = rects_cmid.plot.scatter(x='Lsqrt', y='F', ax=ax, color='green', label='Расчёт по частоте')
ax = rects_approx_c.plot.scatter(x='Lsqrt', y='F', ax=ax, color='yellow', label='Расчёт по теории')

ax.grid(linestyle='--')
# ax.set_xlim(0, 1.1)
# ax.set_ylim(0, 25)
ax.set_xlabel('Lsqrt')
ax.set_ylabel('F')
ax.figure
