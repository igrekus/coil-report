# %% [markdown]
# ### Прямоугольные антенны, диаметр 0.1

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('data/coil_stat.xlsx')
rows = sorted([f'V{n}{d:02d}' for d in range(2, 11) for n in range(1, 12)])
rects = df.loc[(df['file'].isin(rows))]

# %matplotlib inline

# %%
def plot_step_stat(dframe, step, wire, ax=None, color=''):
    res = dframe.loc[(dframe['step (mm)'] == step) & (dframe['wire_dia (mm)'] == wire)][['file', 'wire_dia (mm)', 'wire_len (cm)', 'coil_n', 'L, uH']]
    res = res.sort_values(['coil_n'], ascending=[1])
    ax = res.plot(x='coil_n', y='L, uH', title=f'проводник={wire} мм, шаг={step} мм', ax=ax, color=color, label=f'{step} мм')
    ax1 = ax.twiny()
    res.plot(x='wire_len (cm)', y='L, uH', ax=ax1, color=color)
    ax.grid(linestyle='--')
    ax.set_xlim(0, 12)
    ax.set_ylim(0, 25)
    ax1.set_xlim(0, 295)
    ax1.set_ylim(0, 25)
    ax1.set_xlabel('Длина проводника, см')
    ax1.lines = list()
    ax1.get_legend().remove()
    ax.set_ylabel('Индуктивность, мкГн')
    ax.set_xlabel('Кол-во витков')
    return ax, res

# %%
def plot_coil_n_stat(dframe, coil_n, wire, ax=None, color=''):
    res = dframe.loc[(dframe['coil_n'] == coil_n) & (dframe['wire_dia (mm)'] == wire)][['file', 'wire_dia (mm)', 'step (mm)', 'L, uH']]
    res = res.sort_values(['step (mm)'], ascending=[1])
    ax = res.plot(x='step (mm)', y='L, uH', title=f'проводник={wire} мм, кол-во витков={coil_n}', ax=ax, color=color, label=f'{coil_n} шт')
    ax.grid(linestyle='--')
    ax.set_xlim(0, 1.1)
    ax.set_ylim(0, 25)
    ax.set_ylabel('Индуктивность, мкГн')
    ax.set_xlabel('Шаг, мм')
    return ax, res

# %%
_, res = plot_step_stat(rects, step=0.2, wire=0.1, color='darkblue')
res
# Out:
#       file  wire_dia (mm)  wire_len (cm)  coil_n   L, uH
# 11    V102            0.1         52.796     2.0   1.469
# 51    V202            0.1         76.766     3.0   2.601
# 69    V302            0.1        100.611     4.0   4.019
# 87    V402            0.1        124.296     5.0   5.835
# 118   V502            0.1        147.821     6.0   7.973
# 136   V602            0.1        172.347     7.0  10.282
# 144   V702            0.1        197.043     8.0  13.044
# 152   V802            0.1        221.901     9.0  16.003
# 160   V902            0.1        246.867    10.0  18.471
# 3    V1002            0.1        272.016    11.0  23.000

# %%
_, res = plot_step_stat(rects, step=0.3, wire=0.1, color='darkblue')
res
# Out:
#       file  wire_dia (mm)  wire_len (cm)  coil_n   L, uH
# 13    V103            0.1         52.736     2.0   1.419
# 53    V203            0.1         76.546     3.0   2.432
# 71    V303            0.1        100.207     4.0   3.789
# 89    V403            0.1        123.598     5.0   5.471
# 120   V503            0.1        146.814     6.0   7.370
# 138   V603            0.1        171.342     7.0   9.558
# 146   V703            0.1        196.207     8.0  12.108
# 154   V803            0.1        221.270     9.0  15.267
# 162   V903            0.1        246.575    10.0  17.750
# 5    V1003            0.1        272.215    11.0  20.890

# %%
_, res = plot_step_stat(rects, step=0.4, wire=0.1, color='darkblue')
res
# Out:
#       file  wire_dia (mm)  wire_len (cm)  coil_n   L, uH
# 15    V104            0.1         52.676     2.0   1.334
# 55    V204            0.1         76.413     3.0   2.365
# 73    V304            0.1         99.858     4.0   3.605
# 95    V404            0.1        122.903     5.0   5.038
# 122   V504            0.1        145.725     6.0   6.870
# 140   V604            0.1        170.757     7.0   8.846
# 148   V704            0.1        195.444     8.0  11.301
# 156   V804            0.1        220.527     9.0  13.719
# 164   V904            0.1        246.117    10.0  16.559
# 7    V1004            0.1        272.072    11.0  19.670

# %%
_, res = plot_step_stat(rects, step=0.5, wire=0.1, color='darkblue')
res
# Out:
#       file  wire_dia (mm)  wire_len (cm)  coil_n   L, uH
# 17    V105            0.1         52.616     2.0   1.312
# 57    V205            0.1         76.194     3.0   2.167
# 75    V305            0.1         99.494     4.0   3.458
# 98    V405            0.1        122.217     5.0   5.187
# 124   V505            0.1        144.645     6.0   6.340
# 142   V605            0.1        169.258     7.0   8.482
# 150   V705            0.1        194.393     8.0  10.709
# 158   V805            0.1        219.948     9.0  13.043
# 166   V905            0.1        245.877    10.0  15.698
# 9    V1005            0.1        272.229    11.0  18.660

# %%
_, res = plot_step_stat(rects, step=0.6, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  wire_len (cm)  coil_n  L, uH
# 19   V106            0.1         52.669     2.0  1.332
# 59   V206            0.1         76.397     3.0  2.315
# 77   V306            0.1         99.911     4.0  3.448
# 100  V406            0.1        122.953     5.0  4.893
# 126  V506            0.1        145.837     6.0  6.317

# %%
_, res = plot_step_stat(rects, step=0.7, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  wire_len (cm)  coil_n  L, uH
# 21   V107            0.1         52.722     2.0  1.430
# 61   V207            0.1         76.596     3.0  2.338
# 79   V307            0.1        100.341     4.0  3.447
# 102  V407            0.1        123.854     5.0  4.847
# 128  V507            0.1        146.997     6.0  6.344

# %%
_, res = plot_step_stat(rects, step=0.8, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  wire_len (cm)  coil_n  L, uH
# 23   V108            0.1         52.776     2.0  1.365
# 63   V208            0.1         76.787     3.0  2.281
# 104  V408            0.1        124.618     5.0  4.678
# 130  V508            0.1        147.970     6.0  6.148

# %%
_, res = plot_step_stat(rects, step=0.9, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  wire_len (cm)  coil_n  L, uH
# 25   V109            0.1         52.830     2.0  1.406
# 65   V209            0.1         77.035     3.0  2.205
# 83   V309            0.1        101.209     4.0  3.128
# 106  V409            0.1        125.274     5.0  4.550
# 132  V509            0.1        149.176     6.0  6.031

# %%
_, res = plot_step_stat(rects, step=1.0, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  wire_len (cm)  coil_n  L, uH
# 27   V110            0.1         52.922     2.0  1.413
# 67   V210            0.1         77.237     3.0  2.217
# 85   V310            0.1        101.768     4.0  3.280
# 108  V410            0.1        126.105     5.0  4.602
# 134  V510            0.1        150.463     6.0  5.981

# %%
ax, _ = plot_step_stat(rects, step=0.2, wire=0.1, color='blue')
for st, col in zip([0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0], ['green', 'red', 'orange', 'brown', 'yellow', 'grey', 'lime', 'cyan']):
    plot_step_stat(rects, step=st, wire=0.1, color=col, ax=ax)

# %%
_, res = plot_coil_n_stat(rects, coil_n=2, wire=0.1, color='darkblue')
res
# Out:
#     file  wire_dia (mm)  step (mm)  L, uH
# 11  V102            0.1        0.2  1.469
# 13  V103            0.1        0.3  1.419
# 15  V104            0.1        0.4  1.334
# 17  V105            0.1        0.5  1.312
# 19  V106            0.1        0.6  1.332
# 21  V107            0.1        0.7  1.430
# 23  V108            0.1        0.8  1.365
# 25  V109            0.1        0.9  1.406
# 27  V110            0.1        1.0  1.413

# %%
_, res = plot_coil_n_stat(rects, coil_n=3, wire=0.1, color='darkblue')
res
# Out:
#     file  wire_dia (mm)  step (mm)  L, uH
# 51  V202            0.1        0.2  2.601
# 53  V203            0.1        0.3  2.432
# 55  V204            0.1        0.4  2.365
# 57  V205            0.1        0.5  2.167
# 59  V206            0.1        0.6  2.315
# 61  V207            0.1        0.7  2.338
# 63  V208            0.1        0.8  2.281
# 65  V209            0.1        0.9  2.205
# 67  V210            0.1        1.0  2.217

# %%
_, res = plot_coil_n_stat(rects, coil_n=4, wire=0.1, color='darkblue')
res
# Out:
#     file  wire_dia (mm)  step (mm)  L, uH
# 69  V302            0.1        0.2  4.019
# 71  V303            0.1        0.3  3.789
# 73  V304            0.1        0.4  3.605
# 75  V305            0.1        0.5  3.458
# 77  V306            0.1        0.6  3.448
# 79  V307            0.1        0.7  3.447
# 83  V309            0.1        0.9  3.128
# 85  V310            0.1        1.0  3.280

# %%
_, res = plot_coil_n_stat(rects, coil_n=5, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  step (mm)  L, uH
# 87   V402            0.1        0.2  5.835
# 89   V403            0.1        0.3  5.471
# 95   V404            0.1        0.4  5.038
# 98   V405            0.1        0.5  5.187
# 100  V406            0.1        0.6  4.893
# 102  V407            0.1        0.7  4.847
# 104  V408            0.1        0.8  4.678
# 106  V409            0.1        0.9  4.550
# 108  V410            0.1        1.0  4.602

# %%
_, res = plot_coil_n_stat(rects, coil_n=6, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  step (mm)  L, uH
# 118  V502            0.1        0.2  7.973
# 120  V503            0.1        0.3  7.370
# 122  V504            0.1        0.4  6.870
# 124  V505            0.1        0.5  6.340
# 126  V506            0.1        0.6  6.317
# 128  V507            0.1        0.7  6.344
# 130  V508            0.1        0.8  6.148
# 132  V509            0.1        0.9  6.031
# 134  V510            0.1        1.0  5.981

# %%
_, res = plot_coil_n_stat(rects, coil_n=7, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  step (mm)   L, uH
# 136  V602            0.1        0.2  10.282
# 138  V603            0.1        0.3   9.558
# 140  V604            0.1        0.4   8.846
# 142  V605            0.1        0.5   8.482

# %%
_, res = plot_coil_n_stat(rects, coil_n=8, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  step (mm)   L, uH
# 144  V702            0.1        0.2  13.044
# 146  V703            0.1        0.3  12.108
# 148  V704            0.1        0.4  11.301
# 150  V705            0.1        0.5  10.709

# %%
_, res = plot_coil_n_stat(rects, coil_n=9, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  step (mm)   L, uH
# 152  V802            0.1        0.2  16.003
# 154  V803            0.1        0.3  15.267
# 156  V804            0.1        0.4  13.719
# 158  V805            0.1        0.5  13.043

# %%
_, res = plot_coil_n_stat(rects, coil_n=10, wire=0.1, color='darkblue')
res
# Out:
#      file  wire_dia (mm)  step (mm)   L, uH
# 160  V902            0.1        0.2  18.471
# 162  V903            0.1        0.3  17.750
# 164  V904            0.1        0.4  16.559
# 166  V905            0.1        0.5  15.698

# %%
_, res = plot_coil_n_stat(rects, coil_n=11, wire=0.1, color='darkblue')
res
# Out:
#     file  wire_dia (mm)  step (mm)  L, uH
# 3  V1002            0.1        0.2  23.00
# 5  V1003            0.1        0.3  20.89
# 7  V1004            0.1        0.4  19.67
# 9  V1005            0.1        0.5  18.66

# %%
ax, res = plot_coil_n_stat(rects, coil_n=2, wire=0.1, color='darkblue')
for st, col in zip(range(3, 12), ['red', 'green', 'blue', 'orange', 'yellow', 'lime', 'brown', 'darkgreen', 'grey']):
    plot_coil_n_stat(rects, coil_n=st, wire=0.1, ax=ax, color=col)
