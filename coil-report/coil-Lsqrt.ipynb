# %%
import math
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('data/coil_stat.xlsx')
rows = sorted([f'V{n}{d:02d}' for d in range(2, 12) for n in range(1, 12)])
rects = df.loc[(df['file'].isin(rows))]

# %matplotlib inline

# %%
# rects008 = rects.loc[rects['wire_dia (mm)'] == 0.08]
# rects008.to_excel('rects008.xlsx')

# %%
# rects01 = rects.loc[rects['wire_dia (mm)'] == 0.1]
# rects01.to_excel('rects01.xlsx')

# %%
# rects_teeth = df.loc[df['file'].str.match('VEXPN2')]
# rects_teeth.to_excel('vexpn2xx.xlsx')

# %%
coil_freq = df.loc[df['freq'].notnull() & df['L, uH'].notnull()]
coil_freq['Lsqrt'] = coil_freq['L, uH'].apply(lambda x: 1/math.sqrt(x))
coil_freq
# Out:
# <ipython-input-5-0c67fac3423d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coil_freq['Lsqrt'] = coil_freq['L, uH'].apply(lambda x: 1/math.sqrt(x))
#          file  wire_len (cm)  wire_dia (mm)  step (mm)  coil_n  width (mm)  \
# 38    V123NEW        148.288           0.08        0.2     5.0        44.3
# 40   V123NEW1        119.562           0.08        0.2     4.0        44.3
# 64       V202         76.766           0.08        0.2     3.0        45.0
# 65       V202         76.766           0.10        0.2     3.0        45.0
# 66       V203         76.546           0.08        0.3     3.0        45.0
# ..        ...            ...            ...        ...     ...         ...
# 325  VID1FS25        138.427           0.08        0.3     6.0        44.7
# 327  VID1FS26        146.967           0.08        0.3     6.0        44.7
# 349   VMEDVED         93.797           0.08        0.3     3.0        49.7
# 354      VMO1        111.706           0.10        0.3     4.0        45.0
# 369    VSTAR1        114.483           0.10        0.3     4.0        45.0
#
#      height (mm)  L, uH     freq     q                            mod done  \
# 38          63.2  4.636  17620.0  36.0          rect-inner-rect-5-0-5    +
# 40          63.2  3.253  21370.0  40.0  rect-inner-rect-4-0-4-(3,227)    +
# 64          79.0  2.656  24000.0  22.0                         rect-v  NaN
# 65          79.0  2.601  24000.0  22.0                         rect-v  NaN
# 66          79.0  2.561  24000.0  22.0                         rect-v  NaN
# ..           ...    ...      ...   ...                            ...  ...
# 325         78.5  5.728  14390.0  65.0                              t  NaN
# 327         78.5  6.084  13900.0  63.0                              t  NaN
# 349         78.2  2.777  24000.0  22.0                         medved  NaN
# 354         79.0  4.211  18470.0  59.0                        text-MO    +
# 369         79.0  4.402  18560.0  58.0                              f  NaN
#
#         Lsqrt
# 38   0.464439
# 40   0.554444
# 64   0.613601
# 65   0.620054
# 66   0.624878
# ..        ...
# 325  0.417829
# 327  0.405420
# 349  0.600084
# 354  0.487312
# 369  0.476623
#
# [92 rows x 13 columns]

# %%
coil_freq['Lcalc'] = coil_freq['freq'].apply(lambda f: (0.863) / pow(f / 1000, 2))
coil_freq['Lcalc_sqrt'] = coil_freq['Lcalc'].apply(lambda l: 1 / math.sqrt(l))
coil_freq
# Out:
# <ipython-input-6-332a95677bb5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coil_freq['Lcalc'] = coil_freq['freq'].apply(lambda f: (0.863) / pow(f / 1000, 2))
# <ipython-input-6-332a95677bb5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coil_freq['Lcalc_sqrt'] = coil_freq['Lcalc'].apply(lambda l: 1 / math.sqrt(l))
#          file  wire_len (cm)  wire_dia (mm)  step (mm)  coil_n  width (mm)  \
# 38    V123NEW        148.288           0.08        0.2     5.0        44.3
# 40   V123NEW1        119.562           0.08        0.2     4.0        44.3
# 64       V202         76.766           0.08        0.2     3.0        45.0
# 65       V202         76.766           0.10        0.2     3.0        45.0
# 66       V203         76.546           0.08        0.3     3.0        45.0
# ..        ...            ...            ...        ...     ...         ...
# 325  VID1FS25        138.427           0.08        0.3     6.0        44.7
# 327  VID1FS26        146.967           0.08        0.3     6.0        44.7
# 349   VMEDVED         93.797           0.08        0.3     3.0        49.7
# 354      VMO1        111.706           0.10        0.3     4.0        45.0
# 369    VSTAR1        114.483           0.10        0.3     4.0        45.0
#
#      height (mm)  L, uH     freq     q                            mod done  \
# 38          63.2  4.636  17620.0  36.0          rect-inner-rect-5-0-5    +
# 40          63.2  3.253  21370.0  40.0  rect-inner-rect-4-0-4-(3,227)    +
# 64          79.0  2.656  24000.0  22.0                         rect-v  NaN
# 65          79.0  2.601  24000.0  22.0                         rect-v  NaN
# 66          79.0  2.561  24000.0  22.0                         rect-v  NaN
# ..           ...    ...      ...   ...                            ...  ...
# 325         78.5  5.728  14390.0  65.0                              t  NaN
# 327         78.5  6.084  13900.0  63.0                              t  NaN
# 349         78.2  2.777  24000.0  22.0                         medved  NaN
# 354         79.0  4.211  18470.0  59.0                        text-MO    +
# 369         79.0  4.402  18560.0  58.0                              f  NaN
#
#         Lsqrt     Lcalc  Lcalc_sqrt
# 38   0.464439  0.002780   18.967081
# 40   0.554444  0.001890   23.003776
# 64   0.613601  0.001498   25.834844
# 65   0.620054  0.001498   25.834844
# 66   0.624878  0.001498   25.834844
# ..        ...       ...         ...
# 325  0.417829  0.004168   15.490142
# 327  0.405420  0.004467   14.962680
# 349  0.600084  0.001498   25.834844
# 354  0.487312  0.002530   19.882065
# 369  0.476623  0.002505   19.978946
#
# [92 rows x 15 columns]

# %%
ax_l = coil_freq.plot.scatter(x='Lcalc', y='L, uH')
ax_l.grid(linestyle='--')

# %%
ax_sqrt = coil_freq.plot.scatter(x='Lcalc_sqrt', y='freq')

# %%
coil_freq['Lcalc_adjust'] = coil_freq['Lcalc'].apply(lambda l: l * 4 * pow(math.pi, 2))
coil_freq['coeff'] = coil_freq['L, uH'].apply(lambda l: l / coil_freq['Lcalc'])
coil_freq
# Out:
# <ipython-input-10-c211a8b5b0dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coil_freq['Lcalc_adjust'] = coil_freq['Lcalc'].apply(lambda l: l * 4 * pow(math.pi, 2))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\work\python\coil-report\venv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'coeff'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# d:\work\python\coil-report\venv\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1070         try:
# -> 1071             loc = self.items.get_loc(item)
#    1072         except KeyError:
#
# d:\work\python\coil-report\venv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'coeff'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c211a8b5b0dc> in <module>
#       1 coil_freq['Lcalc_adjust'] = coil_freq['Lcalc'].apply(lambda l: l * 4 * pow(math.pi, 2))
# ----> 2 coil_freq['coeff'] = coil_freq['L, uH'].apply(lambda l: l / coil_freq['Lcalc'])
#       3 coil_freq
#
# d:\work\python\coil-report\venv\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# d:\work\python\coil-report\venv\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
# -> 3001         NDFrame._set_item(self, key, value)
#    3002
#    3003         # check if we are modifying a copy
#
# d:\work\python\coil-report\venv\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3622
#    3623     def _set_item(self, key, value) -> None:
# -> 3624         self._data.set(key, value)
#    3625         self._clear_item_cache()
#    3626
#
# d:\work\python\coil-report\venv\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1072         except KeyError:
#    1073             # This item wasn't present, just insert at end
# -> 1074             self.insert(len(self.items), item, value)
#    1075             return
#    1076
#
# d:\work\python\coil-report\venv\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1179         new_axis = self.items.insert(loc, item)
#    1180
# -> 1181         block = make_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1182
#    1183         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# d:\work\python\coil-report\venv\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3045         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3046
# -> 3047     return klass(values, ndim=ndim, placement=placement)
#    3048
#    3049
#
# d:\work\python\coil-report\venv\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     122
#     123         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 124             raise ValueError(
#     125                 f"Wrong number of items passed {len(self.values)}, "
#     126                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 92, placement implies 1

# %%
ax = coil_freq.plot.scatter(x='Lsqrt', y='freq')
ax.set_xlim(0, 1)
ax.set_ylim(0, 25000)

# %%
coil_working = coil_freq.loc[coil_freq['freq'] < 23500]
coil_working

# %%
ax2 = coil_working.plot.scatter(x='Lsqrt', y='freq')
# ax2.set_xlim(0.3, 0.65)
# ax2.set_ylim(10000, 24000)

# %%
rects

# %%
rects_freq = rects.loc[rects['freq'].notnull() & rects['L, uH'].notnull()]
rects_freq = rects_freq.loc[rects_freq['freq'] < 23500]
rects_freq

# %%
rects_freq['Lsqrt'] = rects_freq['L, uH'].apply(lambda x: 1/math.sqrt(x))
rects_freq

# %%
ax3 = rects_freq.plot.scatter(x='Lsqrt', y='freq')
ax3.set_xlim(0, 1)
ax3.set_ylim(0, 25000)
