# %%
import pandas as pd
import seaborn as sb

# %%
mats = {
1069: 'Neobond 200 г + Хомакол 943 ВР',
1070: 'Neobond 200 г + Хомакол 943 ВР',
1071: 'Neobond 200 г + Хомакол 943 ВР',
1072: 'Neobond 200 г + Хомакол 943 ВР',
1073: 'Neobond 200 г + Хомакол 943 ВР',
1094: 'Neobond 200 г + Nollax S35.3032',
1095: 'Neobond 200 г + Nollax S35.3032',
1096: 'Neobond 200 г + Nollax S35.3032',
1097: 'Neobond 200 г + Nollax S35.3032',
1098: 'Neobond 200 г + Nollax S35.3032',
1119: 'Neobond 200 г + OpSec WRS853',
1120: 'Neobond 200 г + OpSec WRS853',
1121: 'Neobond 200 г + OpSec WRS853',
1122: 'Neobond 200 г + OpSec WRS853',
1123: 'Neobond 200 г + OpSec WRS853',
1144: 'Neobond 200 г + Centro Grafico 125 WB',
1145: 'Neobond 200 г + Centro Grafico 125 WB',
1146: 'Neobond 200 г + Centro Grafico 125 WB',
1147: 'Neobond 200 г + Centro Grafico 125 WB',
1148: 'Neobond 200 г + Centro Grafico 125 WB',
}

# %%
df = pd.read_excel(r'D:\work\python\jupyter\teardown\data\2021-09-30_glues.xlsx', engine='openpyxl')
df_f = pd.read_excel(r'D:\work\python\jupyter\teardown\data\2021-09-30_glues_filtered.xlsx', engine='openpyxl')

# %%
df['mat'] = df.apply(lambda row: mats.get(row['measure']), axis=1)
df_f['mat'] = df_f.apply(lambda row: mats.get(row['measure']), axis=1)

# %%
# ax = sb.lineplot(data=df_f.loc[df_f['mat'] == 'Neobond 200 г + Хомакол 943 ВР'], x='L(mm)', y='ldiff', hue='measure')
ax = sb.lineplot(data=df.loc[df['mat'] == 'Neobond 200 г + Хомакол 943 ВР'], x='L(mm)', y='ldiff', hue='measure')
ax.set(xlim=(0, 10))
ax.set(ylim=(0, 0.3))
fig = ax.get_figure()
fig.set_figwidth(13)
fig.set_figheight(9)

# %%
df_f
# Out:
#       L(mm)  F(N)      deriv                    batch  measure  \
# 0      0.20   0.2        NaN  2021-09-10_no-glue-mats      781
# 1      0.28   0.1  -1.428571  2021-09-10_no-glue-mats      781
# 2      0.35   0.7  12.000000  2021-09-10_no-glue-mats      781
# 3      0.40   3.2  41.666667  2021-09-10_no-glue-mats      781
# 4      0.45   7.0  76.000000  2021-09-10_no-glue-mats      781
# ...     ...   ...        ...                      ...      ...
# 3222   7.91   0.0  -2.500000  2021-09-10_no-glue-mats      810
# 3223   7.96   0.1   1.000000  2021-09-10_no-glue-mats      810
# 3224   8.05   0.0  -2.000000  2021-09-10_no-glue-mats      810
# 3225   8.07   0.1   1.428571  2021-09-10_no-glue-mats      810
# 3226   8.13   0.0  -2.000000  2021-09-10_no-glue-mats      810
#
#                                                mat
# 0        Бумага офсетная для печати «Гознак 200 г»
# 1        Бумага офсетная для печати «Гознак 200 г»
# 2        Бумага офсетная для печати «Гознак 200 г»
# 3        Бумага офсетная для печати «Гознак 200 г»
# 4        Бумага офсетная для печати «Гознак 200 г»
# ...                                            ...
# 3222  Синтетическая бумага «Neobond Classic 150 г»
# 3223  Синтетическая бумага «Neobond Classic 150 г»
# 3224  Синтетическая бумага «Neobond Classic 150 г»
# 3225  Синтетическая бумага «Neobond Classic 150 г»
# 3226  Синтетическая бумага «Neobond Classic 150 г»
#
# [3227 rows x 6 columns]
